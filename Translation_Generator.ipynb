# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
# !pip install torch==1.9.0

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.10.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp38-cp38-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 96.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (2.25.1)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (1.26.14)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.1
#     Uninstalling torchtext-0.14.1:
#       Successfully uninstalled torchtext-0.14.1
# Successfully installed torchtext-0.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.1.2)
# 2023-03-02 18:36:32.748551: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 18:36:35.488047: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 18:36:35.488421: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 18:36:35.488448: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2023-03-02 18:36:51.443662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 18:36:52.487988: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 18:36:52.488119: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 18:36:52.488141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.4.0) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.22.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.10.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.25.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# --2023-03-02 18:37:07--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.03s
#
# 2023-03-02 18:37:07 (239 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2023-03-02 18:37:07--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.03s
#
# 2023-03-02 18:37:08 (289 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
import numpy as np

def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'    
    # scores = QK^T/scale
    scale = np.sqrt(query.shape[0])
    scores = torch.bmm(query, torch.transpose(key, 1, 2)) / scale
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    # output = softmax(scores)(V)
    output = F.softmax(scores, dim=2)

    output = torch.bmm(output, value)
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        
        # Make an attention head (linear layers for q, k, and v)
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        head = nn.ModuleList([nn.Linear(d_model, d_model // h) for i in range(h)])
        self.linears = clones(head, h)
        self.output = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)

        self.h = h
        self.d = d_model

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        final = None

        for head in self.linears:
          Q = head[0](query)
          K = head[1](key)
          V = head[2](value)

          output = attention(Q, K, V, mask)
        
          if final is None:
            final = output
          else:
            final = torch.cat((final, output), 2)
        
        final = self.dropout(final)
        return self.output(final)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.641058 Tokens per Sec: 3187.844971
# Epoch Step: 51 Loss: 5.567814 Tokens per Sec: 5079.358887
# Epoch Step: 101 Loss: 5.857112 Tokens per Sec: 5175.355957
# Epoch Step: 151 Loss: 5.452537 Tokens per Sec: 9945.803711
# Epoch Step: 201 Loss: 5.260503 Tokens per Sec: 10260.744141
# Epoch Step: 251 Loss: 5.419069 Tokens per Sec: 8353.479492
# Epoch Step: 301 Loss: 5.444853 Tokens per Sec: 10380.797852
# Epoch Step: 351 Loss: 4.681069 Tokens per Sec: 9983.257812
# Epoch Step: 401 Loss: 4.679531 Tokens per Sec: 8387.222656
# Epoch Step: 451 Loss: 4.959116 Tokens per Sec: 10248.279297
# Epoch Step: 501 Loss: 4.608517 Tokens per Sec: 10298.045898
# Epoch Step: 1301 Loss: 1.736146 Tokens per Sec: 9483.981445
# Epoch Step: 1 Loss: 2.606129 Tokens per Sec: 2209.525146
# Epoch Step: 51 Loss: 2.709796 Tokens per Sec: 9605.672852
# Epoch Step: 101 Loss: 2.943731 Tokens per Sec: 10270.412109
# Epoch Step: 151 Loss: 2.410772 Tokens per Sec: 8462.466797
# Epoch Step: 201 Loss: 2.382263 Tokens per Sec: 9868.304688
# Epoch Step: 251 Loss: 2.703703 Tokens per Sec: 10065.485352
# Epoch Step: 301 Loss: 2.384247 Tokens per Sec: 8427.761719
# Epoch Step: 351 Loss: 2.580650 Tokens per Sec: 10450.646484
# Epoch Step: 401 Loss: 3.253916 Tokens per Sec: 10484.338867
# Epoch Step: 451 Loss: 2.980969 Tokens per Sec: 8592.979492
# Epoch Step: 501 Loss: 2.705582 Tokens per Sec: 10209.168945
# Epoch Step: 551 Loss: 1.903690 Tokens per Sec: 9864.544922
# Epoch Step: 601 Loss: 2.667009 Tokens per Sec: 8777.202148
# Epoch Step: 651 Loss: 2.326267 Tokens per Sec: 10388.773438
# Epoch Step: 701 Loss: 2.910971 Tokens per Sec: 9171.668945
# Epoch Step: 751 Loss: 2.762628 Tokens per Sec: 9314.434570
# Epoch Step: 801 Loss: 2.431700 Tokens per Sec: 10323.002930
# Epoch Step: 851 Loss: 3.029706 Tokens per Sec: 8779.674805
# Epoch Step: 901 Loss: 2.782747 Tokens per Sec: 10059.714844
# Epoch Step: 951 Loss: 2.121537 Tokens per Sec: 10747.415039
# Epoch Step: 1001 Loss: 2.729253 Tokens per Sec: 8268.145508
# Epoch Step: 1051 Loss: 2.582669 Tokens per Sec: 10272.747070
# Epoch Step: 1101 Loss: 2.882077 Tokens per Sec: 10080.930664
# Epoch Step: 1151 Loss: 2.181923 Tokens per Sec: 8546.706055
# Epoch Step: 1201 Loss: 2.675109 Tokens per Sec: 10469.027344
# Epoch Step: 1251 Loss: 2.620036 Tokens per Sec: 10321.378906
# Epoch Step: 1301 Loss: 2.735647 Tokens per Sec: 8464.894531

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	Ascenderemos juntos
# Translation:	Let us become together
# Target:		We ’ll Ascend Together
#
# Spanish:	Sesión del sacerdocio
# Translation:	Priesthood Session
# Target:		Priesthood Session
#
# Spanish:	De los Setenta
# Translation:	Of the Seventy
# Target:		Of the Seventy
#
# Spanish:	¡ Yo no !
# Translation:	I did not !
# Target:		Not me !
#
# Spanish:	¡ Son reales !
# Translation:	You are true !
# Target:		They are real !
#
# Spanish:	Nosotros seguimos a Jesucristo
# Translation:	We follow Jesus Christ
# Target:		We Follow Jesus Christ
#
# Spanish:	De Él testifico .
# Translation:	I testify that He testify .
# Target:		Of Him I testify .
#
# Spanish:	Cantemos todos a Jesús
# Translation:	We sing all of Jesus Christ to all Jesus Christ to declare Jesus to sing Jesus to sing the sing to the song to bear all .
# Target:		We ’ll sing all hail to Jesus ’ name ,
#
# Spanish:	26 de septiembre de 2015
# Translation:	September 26 , 2015 , 2015
# Target:		September 26 , 2015
#
# Spanish:	Doctrina y Convenios 121:43 .
# Translation:	Doctrine and Covenants clear .
# Target:		Doctrine and Covenants 121:43 .
#
# Spanish:	Véase 2 Pedro 1:4 .
# Translation:	See 2 Peter 1:4 .
# Target:		See 2 Peter 1:4 .
#
# Spanish:	¡ Recuerden quiénes son !
# Translation:	Remember that those who are !
# Target:		Remember who you are !
#
# Spanish:	Él escuchó mi voz .
# Translation:	He heard my voice .
# Target:		He listened to my voice .
#
# Spanish:	Un nuevo mandamiento os doy
# Translation:	A new commandment I give unto you unto you
# Target:		4 . A New Commandment I Give unto You
#
# Spanish:	Conferencia General Semestral Núm . 186
# Translation:	Conference Conference General Conference
# Target:		186th Semiannual General Conference
#
# Spanish:	Por el élder Carlos A. Godoy
# Translation:	By Elder A. Maxwell
# Target:		By Elder Carlos A. Godoy
#
# Spanish:	Luego , seleccione un idioma .
# Translation:	Then they are available .
# Target:		Then select a language .
#
# Spanish:	Mateo 13:19 ; cursiva agregada .
# Translation:	Matthew 5:16 ; emphasis added .
# Target:		Matthew 13:19 ; emphasis added .
#
# Spanish:	Podemos tener la vida eterna .
# Translation:	We can have eternal life .
# Target:		Eternal life can be ours .
#
# Spanish:	Seamos dignos de prestar servicio .
# Translation:	Let us be worthy .
# Target:		Let us be worthy to serve .
#
# Spanish:	Los que sean agradecidos serán glorificados
# Translation:	The Good Things will be grateful
# Target:		Those Who Are Grateful Will Be Made Glorious
#
# Spanish:	cuántas bendiciones de Jesús tendrás .
# Translation:	I understand Jesus .
# Target:		And it will surprise you what the Lord has done .
#
# Spanish:	Éstos son los días de ustedes .
# Translation:	These days are the days of you .
# Target:		These are your days .
#
# Spanish:	Disfruto mucho de la reunión sacramental .
# Translation:	I welcome the sacrament meeting .
# Target:		I greatly enjoy sacrament meeting .
#
# Spanish:	Un grupo bastante grande se fue .
# Translation:	A group group was clear .
# Target:		A rather <unk> <unk> moved out .
#
# Spanish:	“ estuve desnudo , y me cubristeis
# Translation:	“ I went unto me , and ye shall ye abide me ye abide me ye :
# Target:		“ Naked , and ye clothed me .
#
# Spanish:	Hermanos , no le presten atención .
# Translation:	Brethren , not to answer .
# Target:		Brethren , do n’t listen to him .
#
# Spanish:	¿ Qué ha aprendido al escucharlos ?
# Translation:	What has learned to them ?
# Target:		What have you learned as you have listened to them ?
#
# Spanish:	¿ Cuál fue la respuesta de Nefi ?
# Translation:	What was the answer of Nephi ?
# Target:		What was Nephi ’s response ?
#
# Spanish:	Última oración : Élder Shayne M. Bowen .
# Translation:	Benediction : Elder M. Nelson .
# Target:		Benediction : Elder Shayne M. Bowen .
#
# Spanish:	Sí , ¡ podemos ganar y ganaremos !
# Translation:	Yes , we can be !
# Target:		Yes , We Can and Will Win !
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	yo lo sacaré de tinieblas a luz ,
# Translation:	I am like darkness to destroy darkness , light ,
# Target:		That soul , though all hell should endeavor to shake ,
#
# Spanish:	Hagamos que la conferencia sea parte de nuestra vida
# Translation:	Let us choose to be part of our lives from our lives of our lives .
# Target:		Making Conference Part of Our Lives
#
# Spanish:	El presidente Richins lo hizo alegre y gustosamente .
# Translation:	President Clark Jr. did so much and then come .
# Target:		President Richins did so gladly and joyfully .
#
# Spanish:	2 . Para pelear , se necesitan dos personas
# Translation:	2 , for they need two people need two people need two people .
# Target:		2 . To <unk> , You Need Two People
#
# Spanish:	Mateo 5:44 ; véase también 3 Nefi <unk> .
# Translation:	Matthew 10:29 ; see also 3 Nephi 31:20 .
# Target:		Matthew 5:44 ; see also 3 Nephi <unk> .
#
# Spanish:	Esos mandamientos vienen con esta promesa del Señor :
# Translation:	These commandments come unto this promise :
# Target:		Those commandments come with this promise from the Lord :
#
# Spanish:	“ Acuérdate del día del reposo para santificarlo .
# Translation:	“ Remember the Sabbath .
# Target:		“ Remember the sabbath day , to keep it holy .
#
# Spanish:	¿ Cómo iba a pagar los estudios universitarios ?
# Translation:	How was to pay education ?
# Target:		How in the world could I pay for a college education ?
#
# Spanish:	Los que estén en contra , si los hay .
# Translation:	Those opposed , if if if if any .
# Target:		Those opposed , if any .
#
# Spanish:	Véase Hague , William Wilberforce , págs . <unk> .
# Translation:	See William Tyndale , Apr. 8 .
# Target:		See Hague , William Wilberforce , 107–8 .
#
# Spanish:	El ángel Moroni le reveló el Libro de Mormón .
# Translation:	Moroni ’s angel Moroni revealed .
# Target:		The angel Moroni revealed the Book of Mormon .
#
# Spanish:	Deuteronomio <unk> ; 1 Crónicas 16:15 ; Salmo <unk> .
# Translation:	Lectures on 1 ; 1 Kings .
# Target:		Deuteronomy <unk> ; 1 Chronicles 16:15 ; Psalm <unk> .
#
# Spanish:	Seguimos al Señor Jesucristo y enseñamos acerca de Él .
# Translation:	We follow the Lord Jesus Christ and teach His .
# Target:		We follow the Lord Jesus Christ and teach of Him .
#
# Spanish:	Es difícil para nosotros creer lo que no podemos ver
# Translation:	It is difficult to believe what we can not see what we can see what we can see what we can not see what we can not believe .
# Target:		It Is Hard for Us to Believe What We Can not See
#
# Spanish:	¿ Qué significa recibir el don del Espíritu Santo ?
# Translation:	What means to receive the gift of the Holy Ghost ?
# Target:		What Does It <unk> to Receive the Gift of the Holy Ghost ?
#
# Spanish:	“ experimentaron <unk> y azotes … <unk> y <unk> ;
# Translation:	“ I had been able to be able to be healed .
# Target:		“ And … had trial of cruel mockings and <unk> , … of bonds and imprisonment :
#
# Spanish:	La doctrina de la obra del templo y de historia familiar
# Translation:	The doctrine of the temple work and family history history history history story history history history history history history history history .
# Target:		Doctrine of Temple and Family History Work
#
# Spanish:	Se llevó a cabo en un estadio deportivo muy grande .
# Translation:	The high school in a large medical medical school .
# Target:		It was held in a large sports arena .
#
# Spanish:	Ella le preguntó : “ ¿ Me recuerda ? ” .
# Translation:	She asked , “ What did I say unto me ? ”
# Target:		She asked , “ Do you remember me ? ”
#
# Spanish:	el Padre preparó el sitio ideal para que nazca yo .
# Translation:	Father prepared the ideal ideal ideal ideal to us .
# Target:		To help us become what He wants us to be —
#
# Spanish:	Véanse 2 Nefi 5:27 ; Mosíah 4:27 ; Alma <unk> .
# Translation:	See 2 Nephi 2:2 ; Mosiah 7:11–13 ; Alma 7:11–13 .
# Target:		See 2 Nephi 5:27 ; Mosiah 4:27 ; Alma <unk> .
#
# Spanish:	Su Padre Celestial las ama y desea que sean felices .
# Translation:	His Heavenly Father loves and wants you to be happy .
# Target:		Your Heavenly Father loves you and wants you to be happy .
#
# Spanish:	Él me contó de una familia a la que enseñaron .
# Translation:	He told me about a family .
# Target:		He told me of a family they were able to teach .
#
# Spanish:	Sin embargo ese sacrificio podría ser considerado la primera milla .
# Translation:	But that sacrifice could be a clear list .
# Target:		Nevertheless , this sacrifice could be considered part of the first mile .
#
# Spanish:	Aquel matrimonio estuvo sacando lodo y agua casa tras casa .
# Translation:	He was true and water and water .
# Target:		That couple stayed <unk> out mud and water in one home after another .
#
# Spanish:	Afortunadamente , mi sentencia de ir a la cárcel quedó conmutada .
# Translation:	Fortunately , my course was to go .
# Target:		Fortunately , my jail sentence was commuted .
#
# Spanish:	La región <unk> , no muy <unk> , del oeste paraguayo .
# Translation:	The area , not yet the heavy laden , amen .
# Target:		The <unk> , <unk> populated area of western Paraguay .
#
# Spanish:	El Salvador es el Maestro de maestros ; a Él seguimos .
# Translation:	The Savior is the Master of teachers .
# Target:		The Savior is the Master Teacher . We follow Him .
#
# Spanish:	Manual 2 : Administración de la Iglesia , 2010 , 1.3.1 .
# Translation:	Handbook 2 : Administering the Church ( 2010 ) , 522 .
# Target:		Handbook 2 : Administering the Church ( 2010 ) , 1.3.1 .
#
# Spanish:	De ello testifico , en el nombre de Jesucristo . Amén .
# Translation:	I testify in the name of Jesus Christ , amen .
# Target:		I so testify in the name of Jesus Christ , amen .
#
# Spanish:	Simón respondió que era aquel a quien se le perdonó más .
# Translation:	Simon was answered to him .
# Target:		Simon answered that it was the one who was forgiven the most .
#
# Spanish:	Después , fui a la Arboleda Sagrada , donde oré mucho .
# Translation:	After I was the Sacred Grove , where I prayed where I prayed .
# Target:		I went to the Sacred Grove , where I prayed a lot .
#
# Spanish:	Ellos hicieron del evangelio de Jesucristo el centro de su vida .
# Translation:	They did know of the gospel of Jesus Christ .
# Target:		They have made the gospel of Jesus Christ the center of their lives .
#
# Spanish:	Es una subida muy empinada con panoramas impresionantes y <unk> <unk> .
# Translation:	It is a very short time with the heavy and persecution .
# Target:		It is a very steep climb with breathtaking views and <unk> drop - <unk> .
#
# Spanish:	Por lo general , a las mujeres les gusta conversar y reunirse .
# Translation:	So we are to women as we like the women and to be prepared .
# Target:		Women generally love to talk and gather !
#
# Spanish:	Ese don siguió manifestándose en el hospital después de fallecer su esposa .
# Translation:	This gift followed in the hospital after his wife .
# Target:		That gift continued in the hospital after his wife died .
#
# Spanish:	Jesús presentó el reto : “ ¿ Qué pensáis del Cristo ? ”
# Translation:	Jesus spoke : “ What I say unto the Christ ? ”
# Target:		Jesus issued the challenge “ What think ye of Christ ? ”
#
# Spanish:	Hermanos y hermanas , queridos amigos , Dios los conoce de forma perfecta
# Translation:	Brothers and sisters , dear friends , God knows the perfect way of perfect perfect perfect .
# Target:		Brothers and sisters , dear friends , God knows you perfectly .
#
# Spanish:	Véase <unk> <unk> , <unk> <unk> for All Occasions ( 2013 ) .
# Translation:	See Psalm 20:28 , please manifest it ( 2013 ) , 2013 .
# Target:		See <unk> <unk> , <unk> Quotes for All Occasions ( 2013 ) .
#
# Spanish:	Ella quedó embarazada de una breve relación , y sus adicciones continuaron ;
# Translation:	She was filled with a short of emotional , and his weaknesses .
# Target:		She became pregnant from a brief relationship , and her addictions continued .
#
# Spanish:	Cuando ellos cumplen sus promesas , sienten el Espíritu en su vida .
# Translation:	When they are their promises , feel your life in your life .
# Target:		As they keep their promises , they feel the Spirit in their lives .
#
# Spanish:	Parecía como si tuviera un resplandor celestial alrededor de su pequeño cuerpo .
# Translation:	It seemed like if a celestial brightness of joy .
# Target:		It seemed as though he had a celestial glow around his little body .
#
# Spanish:	Nuevamente comprendí que el poder real del templo está en las ordenanzas .
# Translation:	I then remember the power of the temple is in the temple .
# Target:		I realized again that the real power of the temple is in the ordinances .
#
# Spanish:	Él se casó con Emily Keep en <unk> y tuvieron ocho hijos .
# Translation:	He married with his enemies and they were raised .
# Target:		He married Emily Keep in <unk> , and they became the parents of eight children .
#
# Spanish:	Entonces acudimos a Él , <unk> sujetarnos al Hijo Unigénito de Dios .
# Translation:	Then we will sustain Him , they will be the Only of God .
# Target:		Then we reach for Him , yearning to yoke ourselves to the Only Begotten Son of God .
#
# Spanish:	Jesús ha curado ya mi cáncer y los de ustedes , … mejoraré .
# Translation:	Jesus has cancer for cancer and my cancer .
# Target:		Jesus has already cured my cancer , and yours .
#
# Spanish:	( 126 ) Una jovencita supera la tentación por asistir a la Mutual .
# Translation:	( 126 ) A young woman is available to attend the new general board .
# Target:		( 126 ) A young woman overcomes temptation by attending Mutual .
#
# Spanish:	No puedo recordar no haber creído en el Padre Celestial y en Jesucristo .
# Translation:	I can not remember that the things in Heavenly Father and Jesus Christ .
# Target:		I ca n’t remember not believing in Heavenly Father and Jesus Christ .
#
# Spanish:	Él contó que compró una granja muy descuidada en Canadá hace muchos años .
# Translation:	He told him a release to be a very close in many years ago .
# Target:		He told of <unk> a <unk> farm in Canada many years ago .
#
# Spanish:	D. y C. <unk> ; véase también D. y C. 41:1 , 12 .
# Translation:	Doctrine and Covenants 128:22 ; see also D&C 82:10 .
# Target:		Doctrine and Covenants <unk> ; see also Doctrine and Covenants 41:1 , 12 .
#
# Spanish:	El presidente Monson también habló de Gedeón , un héroe del Antiguo Testamento .
# Translation:	President Monson also spoke of a constant gift , a sign of the Old Testament .
# Target:		President Monson also spoke of Gideon , a hero in the Old Testament .
#
# Spanish:	Hay seguridad en seguir la palabra del Señor por medio de Sus profetas .
# Translation:	There are safety in the word of the Lord ’s prophets through His prophets .
# Target:		There is safety in following the word of the Lord through His prophets .
#
# Spanish:	Tienen el beneficio de sostener en sus manos el Libro de Mormón completo .
# Translation:	They are the right to please sustain their hands .
# Target:		You have the benefit of holding in your hands the complete Book of Mormon .
#
# Spanish:	Tiene que ver con el niño que quizá diga que no está escuchando .
# Translation:	It is that the child may say that if you are listening to .
# Target:		And it is about one little boy who might claim he is not listening .
#
# Spanish:	Nuestro Redentor elige perdonar debido a Su compasión , misericordia y amor incomparables .
# Translation:	Our Redeemer are tempted to His compassion , and mercy , and the pure love .
# Target:		Our Redeemer chooses to forgive because of His incomparable compassion , mercy , and love .
#
# Spanish:	Llamó a un pequeñito , lo colocó en medio de ellos y dijo :
# Translation:	She would like a little boy , through them and said :
# Target:		He called a little child to Him and set him in the midst of them and said :
#
# Spanish:	“ En verdad os digo que esta viuda pobre echó más que todos .
# Translation:	“ I say unto you , this widow that the poor that all that is more .
# Target:		“ Of a truth I say unto you , that this poor widow hath cast in more than they all :
#
# Spanish:	¿ Ven la relación que hay entre las llaves del sacerdocio y las bendiciones ?
# Translation:	Will you see the relationship between priesthood keys and blessings ?
# Target:		Can you see the relationship between priesthood keys and blessings ?
#
# Spanish:	La expiación del Salvador está a disposición de cada uno de nosotros , siempre .
# Translation:	The Savior ’s Atonement is available to each of us .
# Target:		The Savior ’s Atonement is available to each of us — always .
#
# Spanish:	Se casó en el templo con su novia de la escuela secundaria , Bayley .
# Translation:	The temple married with his own temple school , his school , Aroldo .
# Target:		He married his high school sweetheart , Bayley , in the temple .
#
# Spanish:	Los antecedentes singulares de Pablo lo prepararon para relacionarse con gente de muchas culturas .
# Translation:	Those precious news from Paul to help people in many people .
# Target:		Paul ’s unique background prepared him to relate to people of many cultures .
#
# Spanish:	" Deja que el Espíritu te enseñe " , Himnos , nro . 77 .
# Translation:	" Let thee teach thee unto thee , " Hymns , no . "
# Target:		" Let the Holy Spirit Guide , " Hymns , no . 143 .
#
# Spanish:	Después de enseñarles , el Salvador se marchó y prometió regresar al día siguiente .
# Translation:	After teach them , the Savior came and was prepared to return to the next day .
# Target:		After teaching them , the Savior departed and promised to return the next day .
#
# Spanish:	Mis queridas hermanas , esta noche hemos sido bendecidos por el Espíritu de Dios .
# Translation:	My dear sisters , this evening we have been blessed by the Spirit of God .
# Target:		My dear sisters , we have been blessed by the Spirit of God tonight .
#
# Spanish:	En ocasiones el mensaje será lo más importante que compartan en una visita particular .
# Translation:	Sometimes the message will be important to a visit in particular visit .
# Target:		Sometimes the message will be the most important thing you share on a particular visit .
#
# Spanish:	Tercero , el don del Espíritu Santo se recibe mediante la imposición de manos .
# Translation:	Third , the gift of the Holy Ghost is through the hands of the hands .
# Target:		Third , the gift of the Holy Ghost comes by the laying on of hands .
#
# Spanish:	Al mismo tiempo la madre de Ben , <unk> , afrontaba sus propios obstáculos .
# Translation:	At the same time of Elizabeth , Elizabeth , she would feel their own trials .
# Target:		At the same time , Ben ’s mother , <unk> , faced obstacles of her own .
#
# Spanish:	Las Escrituras declaran : “ Si no recibís el Espíritu , no enseñaréis ” .
# Translation:	The scriptures , “ If ye not remember the Spirit , ye shall not be forgiven . ”
# Target:		The scriptures state , “ If ye receive not the Spirit ye shall not teach . ”
#
# Spanish:	Al adorar , abrimos nuestro corazón al poder sanador de la expiación de Jesucristo .
# Translation:	We worship , we open our hearts to the healing of the Atonement of Jesus Christ .
# Target:		When we worship , we open our hearts to the healing power of the Atonement of Jesus Christ .
#
# Spanish:	Mientras descendíamos un nivel más , alegremente explicó que estaba en camino al templo .
# Translation:	While we entered the current way , he explained the path to the temple .
# Target:		As we traveled down one more level , he cheerfully explained that he was on his way to the temple .
#
# Spanish:	Para recibir esa guía se necesitará más que sólo escuchar y leer de forma superficial .
# Translation:	For that guidance will be done by hearing and read only and read it .
# Target:		Getting that guidance will take more than casual listening and reading .
#
# Spanish:	Todos los que obedecen Sus mandamientos obtendrán las bendiciones más gloriosas que se pueda imaginar .
# Translation:	All who obey His commandments .
# Target:		All who obey His commandments will earn the most glorious blessings imaginable .
#
# Spanish:	Cuando su amigo le expresó lo que pensaba , Brian sintió la confirmación del Espíritu .
# Translation:	When his friend expressed what he thought , Elder Perry felt the confirmation of the Spirit .
# Target:		As his friend expressed his feelings , Brian felt the Spirit ’s confirmation .
#
# Spanish:	Por todo el mundo , ésta es una época de inestabilidad económica e incertidumbre financiera .
# Translation:	For all the world , this is a time of time and confusion and life .
# Target:		Across the world , this is a time of economic instability and financial uncertainty .
#
# Spanish:	Mi mensaje se centra en el principio de retener siempre la remisión de nuestros pecados .
# Translation:	My message focuses on the beginning of the remission of the remission of our sins .
# Target:		My message focuses upon the principle of always retaining a remission of our sins .
#
# Spanish:	Pero , ¿ cómo hicieron los <unk> y <unk> hasta que se resolvió el problema ?
# Translation:	But how did they were able to be able to be able to the problem ?
# Target:		But how did the <unk> and <unk> get along until the problem was solved ?
#
# Spanish:	Nuestra doctrina más fundamental incluye el conocimiento de que somos hijos de un Dios viviente .
# Translation:	Our doctrine includes the knowledge of the knowledge of God that we are a living living living living God .
# Target:		Our most fundamental doctrine includes the knowledge that we are children of a living God .
#
# Spanish:	Y él me dijo : “ Necesitamos ver cómo podemos conseguir que él siga viniendo .
# Translation:	And he said , “ I need to see how we need to see him .
# Target:		And he said , “ We need to figure out how to keep him coming .
#
# Spanish:	El Señor dijo : “ Es preciso que se haga a mi propia manera ” .
# Translation:	The Lord said , “ It is my own way to be done . ”
# Target:		The Lord has said , “ It must needs be done in mine own way . ”
#
# Spanish:	¡ Qué maravillosa bendición tenemos de recibir hijos e hijas de Dios en nuestro hogar !
# Translation:	What wonderful blessing we have the blessing of God and daughters in our home !
# Target:		What a wonderful blessing we have to receive sons and daughters of God into our home .
#
# Spanish:	y no porque fuera más lista , más bella ni más capaz que sus hermanas .
# Translation:	And because they are not the list , or more than they will be more than sisters .
# Target:		And it was n’t because she was <unk> or more beautiful or more capable than her sisters .
#
# Spanish:	Cuando Robert D. Hales <unk> un piso se encierra en una esquina ( 24 ) .
# Translation:	When Robert D. Hales was a window in a window ( 24 ) , he met .
# Target:		Robert D. Hales <unk> a floor until he gets himself stuck in a corner ( 24 ) .
#
# Spanish:	Tal es el caso cuando enseñamos “ de acuerdo con las manifestaciones del Espíritu ” .
# Translation:	It is the case when we teach “ we teach the Spirit of the Spirit . ”
# Target:		Such is the case when we teach “ after the manner of the workings of the Spirit . ”
#
# Spanish:	<unk> interés sincero en su bienestar y después comparte tu testimonio del evangelio de Jesucristo .
# Translation:	They are honest in your well - being responsible and his testimony of Jesus Christ .
# Target:		Show your sincere interest in their well - being ; then share your testimony of the gospel of Jesus Christ .
#
# Spanish:	Estaría como antes de conocer la Iglesia , cuando buscaba conocimiento , fe y esperanza .
# Translation:	You will be before the Church , when they asked , knowledge , knowledge , hope and hope .
# Target:		I would be just like I was before I found the Church , when I was searching for knowledge , faith , and hope .
#
# Spanish:	El meditar sobre un pasaje de Escrituras como ése , da gran dirección a nuestra vida .
# Translation:	The scripture study about this scripture as the great direction of our lives , to our lives .
# Target:		Pondering a scripture like that gives great direction to life .
#
# Spanish:	En sus conversaciones cotidianas , ustedes pueden añadir a la fe que ellos tienen en Cristo .
# Translation:	In your particular efforts , you can add to faith that they have faith in Christ .
# Target:		In your everyday conversations you can add to their faith in Christ .
#
# Spanish:	Hay personas que luchan todos los días con problemas ; mostrémosles nuestro interés , y <unk> .
# Translation:	There are all to all days with our problems .
# Target:		Let us extend to them our concern , as well as a helping hand .
#
# Spanish:	A través de todo ello , encontró una manera de aprender con sus hermanos del sacerdocio .
# Translation:	Through this , this way he found a way with their brethren .
# Target:		Through it all , he found a way to learn with his priesthood brethren .
#
# Spanish:	Para una deuda personal , esa es una suma <unk> , totalmente fuera de nuestra comprensión .
# Translation:	For a personal personal personal , this is totally clean from our understanding of our understanding .
# Target:		As a personal debt , that is an <unk> number — totally beyond our comprehension .
#
# Spanish:	El presidente Gordon B. Hinckley enseñó que nuestro mensaje al mundo es que ¡ Él vive !
# Translation:	President Gordon B. Hinckley taught our message to the world that is the world that He lives !
# Target:		President Gordon B. Hinckley taught that our message to the world is that He lives !
#
# Spanish:	Para vivir por el Espíritu , nuestro estilo de vida debe reflejar rectitud ante el Señor .
# Translation:	For living by the Spirit , our lives must be able to reflect before righteousness .
# Target:		And to live in the Spirit , our lifestyle must reflect righteousness before the Lord .
#
# Spanish:	En las Escrituras leemos que el adversario es “ el fundador de todas estas cosas ” .
# Translation:	In the scriptures we read the adversary is “ the things of all these things . ”
# Target:		The scriptures tell us that the adversary is “ the founder of all these things . ”
#
# Spanish:	Mediante Jesucristo y el poder que recibimos por medio de Su expiación nosotros también podemos servir .
# Translation:	Through Jesus Christ and the power we receive His Atonement through us can also serve .
# Target:		Through Jesus Christ and the power we receive through His Atonement , we can also serve .
#
# Spanish:	Miles de ustedes tuvieron sentimientos de compasión al saber de las inundaciones en <unk> , Australia .
# Translation:	Thousands of you had compassion to know the feelings of the boat , they were to serve .
# Target:		<unk> of sympathy came to thousands of you who learned of the flooding in <unk> , Australia .
#
# Spanish:	Hablo desde la perspectiva del evangelio de Jesucristo , lo que incluye Su plan de salvación .
# Translation:	I speak of the perspective of the gospel of Jesus Christ , includes His plan .
# Target:		I speak from the perspective of the gospel of Jesus Christ , including His plan of salvation .
#
# Spanish:	Oramos para acercarnos a nuestro Padre Celestial , para recibir Su Espíritu y sentir Su amor .
# Translation:	We pray for ourselves to draw His Spirit , to receive His Spirit and feel His love .
# Target:		We pray to be close to our Heavenly Father , to receive His Spirit and feel His love .
#
# Spanish:	Él escribió : “ En esplendor , no hay ciudad que se le … asemeje ” .
# Translation:	He wrote , “ In the city , there is no city . ”
# Target:		“ In magnificence , ” he wrote , “ there is no other city that approaches … it . ”
#
# Spanish:	Cuando llegamos a la cima , <unk> hasta una cresta rocosa llamada “ <unk> Back ” .
# Translation:	When we become the top , the cat , he was “ a lot of the wrong . ”
# Target:		Once over the top we dropped down into a rocky ridge to a place we called “ <unk> Back . ”
#
# Spanish:	¿ Cómo podía ser rey ? ; pero Dios lo vio como “ joven y apuesto ” .
# Translation:	How could he be King of God ? but he saw the young man as “ a man . ”
# Target:		But God saw him as “ a choice young man . ”
#
# Spanish:	Mis jóvenes hermanos y hermanas , conocer a Dios es una lucha que dura toda una vida .
# Translation:	My young men and sisters , God is a small or that God ’s life .
# Target:		My young brothers and sisters , knowing God is the quest of a lifetime .
#
# Spanish:	Representa una increíble guía de los cielos con respecto a la humildad y a la obra misional .
# Translation:	This difficult , guidance of heaven regarding humility and humility and the work .
# Target:		<unk> It gives incredible direction from heaven with respect to humility and missionary work .
#
# Spanish:	El joven , que tenía treinta años , se había unido a la Iglesia cuando era adolescente .
# Translation:	The young , who had 30 years , I had met with a teenager when a teenager .
# Target:		This 30 - year - old man had joined the Church in his late teens .
#
# Spanish:	A lo largo de los años he efectuado la ordenanza selladora de muchas parejas ilusionadas y enamoradas .
# Translation:	Over the years I have received the ordinance of many ordinance and many couples love .
# Target:		Over the years , I have performed the sealing ordinance for many hopeful and loving couples .
#
# Spanish:	“ Se ha dicho que en una época el sol nunca se ponía sobre el imperio británico .
# Translation:	“ The good thing has said in a time to be never been baptized .
# Target:		“ It was said that at one time the sun never set on the British Empire .
#
# Spanish:	A pedido de los padres , muchos jóvenes que aman el Evangelio esperan años para ser bautizados .
# Translation:	To have asked , many young men who love the gospel to be baptized for many years .
# Target:		At the request of parents , many youth who love the gospel wait years to be baptized .
#
# Spanish:	Robert L. Millet , After All We Can Do : Grace Works , 2003 , pág. 133 .
# Translation:	Robert L. Andersen , Why Can We Can We ( 2003 ) , 2003 , emphasis added .
# Target:		Robert L. Millet , After All We Can Do : Grace Works ( 2003 ) , 133 .
#
# Spanish:	En el Libro de Mormón aprendemos de un pueblo que había descubierto el secreto de la felicidad .
# Translation:	In the Book of Mormon we learn from a people who had found the happiness of happiness .
# Target:		In the Book of Mormon we learn of a people who had discovered the secret to happiness .
#
# Spanish:	Aun cuando el auto tenía un potencial enorme , sin las llaves no podía cumplir su función .
# Translation:	Even when the car had a large time , he could not fulfill the keys .
# Target:		Even though the car had great potential , without keys , it could not perform its intended function .
#
# Spanish:	“ Porque así como en Adán todos mueren , así también en Cristo todos serán vivificados ” .
# Translation:	“ For as Adam all in all things , they are also in Christ . ”
# Target:		“ For as in Adam all die , even so in Christ shall all be made alive . ”
#
# Spanish:	A <unk> empezó a hacerlo , indicando que tomaría mucho tiempo cocinar ese viejo y duro <unk> .
# Translation:	He began to do so , we were so much much time to be old and then been able to be able to be able to be able to be .
# Target:		<unk> she started the job , indicating it would take a long time to cook that tough old thing .
#
# Spanish:	<unk> de la naturaleza divina de la obra , aceptó actuar como escribiente para completar la traducción .
# Translation:	They are the divine nature of divine work , as he would act as a translation .
# Target:		<unk> of the divine nature of the work , Oliver agreed to act as scribe in completing the translation .
#
# Spanish:	Cuando pienso en nuestros grandes antepasados pioneros , siento que todos vamos <unk> a hombros de gigantes .
# Translation:	When I think of our ancestors , I feel that all the shoulders of the shoulders .
# Target:		When I think of our great pioneer forefathers , I feel that we are all standing on the shoulders of giants .
#
# Spanish:	Elegimos creer cuando ayunamos , cuando guardamos el día de reposo y cuando adoramos en el templo .
# Translation:	We are to believe when we keep the Sabbath day day when we worship and we worship in the temple .
# Target:		We are choosing to believe when we fast , when we keep the Sabbath day holy , and when we worship in the temple .
#
# Spanish:	Habla con tus padres en cuanto a algunas de las cosas que él sugirió que dejáramos de hacer .
# Translation:	He speaks with your parents to some of the things that he would do to do .
# Target:		Talk with your parents about some of the behaviors he suggested we stop .
#
# Spanish:	Los profetas siempre han advertido acerca del orgullo y de hacer hincapié en las cosas vanas del mundo .
# Translation:	The prophets have always always warned of pride and do good things to do the things of the world .
# Target:		The prophets have always warned about pride and emphasizing the vain things of the world .
#
# Spanish:	No tienen que esperar a que llegue su llamamiento oficial para estar anhelosamente consagrados a la obra misional .
# Translation:	You have not to wait to be a calling to be able to be engaged in missionary work .
# Target:		You need not wait for your official call to become anxiously engaged in missionary work .
#
# Spanish:	¿ Cómo pueden asegurarse de que su comportamiento en el día de reposo les traiga gozo y regocijo ?
# Translation:	How can you see that your behavior on the Sabbath day ?
# Target:		How can you ensure that your behavior on the Sabbath will lead to joy and rejoicing ?
#
# Spanish:	En este día especial , testifico que Dios , nuestro Padre , y Su Amado Hijo , viven .
# Translation:	In this day I testify that God , that God our Father and His Beloved Son , His Beloved Son , live .
# Target:		On this very special day , I testify that God our Father and His Beloved Son live .
#
# Spanish:	Con Sus palabras y Su ejemplo , Cristo nos ha mostrado la forma de acercarnos más a Él .
# Translation:	With His words and His example , Christ has shown us the more powerful than we become more .
# Target:		By His words and His example , Christ has shown us how to draw closer to Him .
#
# Spanish:	Con la tecnología actual , sólo estamos a un clic de cualquier información sobre una <unk> de temas .
# Translation:	With technology , we are only , we are only a different information about a public discourse .
# Target:		With technology today , information on a myriad of subjects is available with the click of a <unk> .
#
# Spanish:	Boyd K. Packer , en “ Donna Smith Packer Receives Family History Certificate from BYU ” , news.byu.edu/archive12-jun-packer.aspx .
# Translation:	Boyd K. Packer , “ The Family History Library , ” of World War II , Feb. 27 .
# Target:		Boyd K. Packer , in “ Donna Smith Packer Receives Family History Certificate from BYU , ” news.byu.edu/archive12-jun-packer.aspx .
#
# Spanish:	Como yo era el menor y deseaba sentirme integrado , me convencieron para que saltara y la probara .
# Translation:	As I was the young and I wanted to be able to turn and leave it to be alone .
# Target:		Being the youngest and wanting to fit in , I was persuaded to jump in and try it out .
#
# Spanish:	entonces puedes pedir con fe , sin dudar en nada , según tus necesidades , y Dios responderá .
# Translation:	You can ask faith in your own , without your needs , according to God and answer .
# Target:		Then you can ask in faith , nothing wavering , according to your need , and God will answer .
#
# Spanish:	El mantener esa meta eterna ante los jóvenes que ustedes guían es el mejor regalo que podrían darles .
# Translation:	The goal will keep that eternal goal would be the very gift to give the gift that is to give .
# Target:		Holding that eternal goal before the youth you lead is as great a gift as you could give them .
#
# Spanish:	Esos meses fueron una época emotiva para toda la familia mientras esperábamos e <unk> la ayuda del Señor .
# Translation:	These months were a time for all of all the family and the Lord ’s help .
# Target:		Those months were a tender time for all the family as we hoped and petitioned the Lord for His help .
#
# Spanish:	<unk> el sacerdocio de Dios es ser considerado responsable ante Dios de la vida eterna de Sus hijos .
# Translation:	They are the priesthood of God is a strong place of God ’s eternal life .
# Target:		To hold the priesthood of God is to be held responsible by God for the eternal lives of His children .
#
# Spanish:	Tan pronto como escuché esa voz , en una fracción de segundo <unk> : “ No puedes <unk> .
# Translation:	As soon as I heard that as a second voice : “ I can not be done not .
# Target:		As quick as I heard this voice , in a split second , I rationalized : “ You ca n’t stop .
#
# Spanish:	tenía la reputación de ser crítico de la Iglesia y tenía demasiado orgullo para pedir que lo <unk> .
# Translation:	I had the Church to be too far from pride and had too too too much to ask him .
# Target:		He had developed a reputation as a critic of the Church , and he had too much pride to ask to be readmitted .
#
# Spanish:	En muchos pasajes de las Escrituras se hace referencia al poder de la fe para sanar a una persona .
# Translation:	In many scriptures , the scriptures makes the power of faith to heal faith for a person .
# Target:		Many scriptures refer to the power of faith in the healing of an individual .
#
# Spanish:	( 52 ) <unk> oran por los prisioneros de la Segunda Guerra Mundial a los que van a rescatar .
# Translation:	( Abraham 3:25 ) , please fall .
# Target:		( 52 ) <unk> pray for the World War II prisoners they will go save .
#
# Spanish:	M. Russell Ballard , “ <unk> los consejos ” , Liahona , enero de 1994 , págs . <unk> .
# Translation:	M. Russell Ballard , “ The Challenge , ” Ensign , Nov. 1994 , 86 .
# Target:		M. Russell Ballard , “ Strength in Counsel , ” Ensign , Nov. 1993 , 76 .
#
# Spanish:	Satanás sostendrá que es socialmente aceptable dudar de los dones espirituales y de las enseñanzas de los profetas verdaderos .
# Translation:	Satan will be willing to doubt that they will choose the spiritual gifts and the teachings of the prophets .
# Target:		Satan will advocate that it is cool to doubt spiritual gifts and the teachings of true prophets .
#
# Spanish:	Después de aceptar un poco de licor , Rip se siente <unk> y cierra los ojos por un rato .
# Translation:	After accept a little , a little thing , it is to be fulfilled by the eyes .
# Target:		After accepting some of their liquor , Rip becomes <unk> and <unk> his eyes for a moment .
#
# Spanish:	¿ Somos culpables de subestimar el más grande de los dones que se nos puede ofrecer en esta vida ?
# Translation:	Are we ever trying to be more more than we are to offer the gifts of this life can we offer in this life ?
# Target:		Are we ever guilty of being complacent about the greatest gift we can be offered in this life ?
#
# Spanish:	Thomas S. Monson , “ Bienvenidos a la conferencia ” , Liahona , mayo de 2009 , pág. 6 .
# Translation:	Thomas S. Monson , “ Welcome to Conference , ” Ensign , May 2009 , 2009 , May 2009 , 6 .
# Target:		Thomas S. Monson , “ Welcome to Conference , ” Ensign or Liahona , Nov. 2009 , 6 .
#
# Spanish:	Sé que sus ofrendas consagradas , sus blancas de la viuda , fueron conocidas y aceptadas por el Señor .
# Translation:	I know that their fast offerings , in the widow , were given up and the Lord .
# Target:		I know that their consecrated offerings , their widow ’s mites , were known and accepted by the Lord .
#
# Spanish:	El tercero da una visión de la misión del Salvador para la salvación de los hijos del Padre Celestial .
# Translation:	The third - year - the mission of salvation for salvation for the Savior ’s children .
# Target:		The third gives a vision of the Savior ’s mission for the salvation of Father in Heaven ’s children .
#
# Spanish:	Comenzó Su misión a los treinta años y citó las Escrituras frecuentemente y desde el comienzo de Su ministerio .
# Translation:	He began to age 18 , and He looked up and on the scriptures and on the beginning .
# Target:		He began his mission at age 30 , and He referenced the scriptures early and often throughout His ministry .
#
# Spanish:	Cuando Isaías describió el día de reposo como una “ delicia ” , también nos enseñó cómo hacerlo deleitable .
# Translation:	When Isaiah described the Sabbath as “ a delight , we also also also teach us how to do it . ”
# Target:		When Isaiah described the Sabbath as “ a delight , ” he also taught us how to make it delightful .
#
# Spanish:	como éramos pocos , se llamaba a los jóvenes a participar activamente en todos los aspectos de la rama .
# Translation:	As we were few , I was called to participate in all the other of the branch .
# Target:		Because our numbers were few , the youth were called upon to actively participate in all aspects of the branch .
#
# Spanish:	Años después de bautizarme , mi padre se bautizó , y luego mi familia se selló en el templo .
# Translation:	Years later , I was baptized , my father was baptized , and then was sealed in the temple .
# Target:		Many years after I was baptized , my father was baptized , and later my family was sealed in the temple .
#
# Spanish:	Recibieron un informe de que “ toda la misión estaba despierta a medianoche , saltando en las camas ” .
# Translation:	The now of all the mission was “ my mission , I was at the night , the door . ”
# Target:		The report came back that the “ whole mission was awake in the middle of the night jumping on their beds . ”
#
# Spanish:	Recibir la autoridad del sacerdocio por la imposición de manos es un comienzo importante , pero no es suficiente .
# Translation:	They authority for priesthood authority is a beginning of hands , but it is not always always important , but it is always enough .
# Target:		Receiving the authority of the priesthood by the laying on of hands is an important beginning , but it is not enough .
#
# Spanish:	Siguió al Salvador , que enseñó : “ Aquello que me habéis visto hacer , eso haréis vosotros ” .
# Translation:	I remembered the Savior , taught , “ What ye have seen me , that ye shall have done unto you . ”
# Target:		He followed the Savior , who taught , “ The works which ye have seen me do that shall ye also do . ”
#
# Spanish:	Ciertamente no podremos hacer eso si <unk> el discipulado arrastrando los pies , pendientes del reloj , <unk> constantemente .
# Translation:	We can not do this that if the discipleship would be able to be the dance of the poor , they can be able to be able to be done .
# Target:		We certainly can not do this with a dragging - our - feet , staring - at - our - watch , complaining - as - we - go approach to discipleship .
#
# Spanish:	Tengan a la vista en su casa una lámina de uno de los templos para que los hijos la vean .
# Translation:	Whether you seek the house of your house to be a temples for temples to see the children which will see the children see .
# Target:		Keep a picture of a temple in your home that your children may see it .
#
# Spanish:	Allí , a veces , el velo entre nosotros y los que están al otro lado se vuelve muy tenue .
# Translation:	There are times , the veil between us and those who are another side in the side of the other .
# Target:		Occasionally in the temple the veil between us and those on the other side becomes very thin .
#
# Spanish:	Véase de L. Whitney Clayton , “ Elijamos creer ” , Liahona , mayo de 2015 , págs . <unk> .
# Translation:	See L. Whitney , “ Draw Me , ” Ensign or Liahona , May 2015 , 2015 , May 2015 , 52 .
# Target:		See L. Whitney Clayton , “ Choose to Believe , ” Liahona , May 2015 , <unk> .
#
# Spanish:	Durante el viaje se encontraron con el padre de Lamoni , quien era el rey lamanita de toda la tierra .
# Translation:	During the trip with the father of the king , who was the king of all the king .
# Target:		During their journey they encountered Lamoni ’s father , who was the Lamanite king over all the land .
#
# Spanish:	Véase de Richard E. Turley Jr . , Victims : The LDS Church and the Mark <unk> <unk> , 1992 .
# Translation:	See Richard E. Faust Jr.
# Target:		See Richard E. Turley Jr. , Victims : The LDS Church and the Mark <unk> <unk> ( 1992 ) .
#
# Spanish:	El elegir lo justo constantemente , cuando tengamos que tomar una decisión , crea el terreno firme bajo nuestra fe .
# Translation:	The choose to choose , when we have to make a clear decision , the way to exercise faith in our faith .
# Target:		Our choosing the right consistently whenever the choice is placed before us creates the solid ground under our faith .
#
# Spanish:	Véase M. Russell Ballard , “ Madres e hijas ” , Liahona , mayo de 2010 , págs . <unk> .
# Translation:	See M. Russell Ballard , “ My daughters , ” Ensign , May 2010 , 2010 , May 2010 , 522 .
# Target:		See M. Russell Ballard , “ Mothers and Daughters , ” Liahona and Ensign , May 2010 , <unk> .
#
# Spanish:	Tras la muerte de Moisés , Josué fue llamado por Dios para ser el profeta que <unk> ese milagroso trayecto .
# Translation:	After Moses ’s death , Joshua was called to God to be called to be saved .
# Target:		At Moses ’s death , Joshua was called by God to be the prophet who would complete this miraculous journey .
#
# Spanish:	Me encanta estudiar y meditar sobre la vida de Él , quien dio todo por mí y por todos nosotros .
# Translation:	I love and ponder the life of life , who gave all of me , who gave all us all us all .
# Target:		I love to study and ponder the life of Him who gave everything for me and for all of us .
#
# Spanish:	Esos falsos profetas y sus seguidores “ no creían en el arrepentimiento de sus pecados ” ( Alma 15:15 ) .
# Translation:	These prophets and apostles and followers “ did not believe in the sins of repentance ” ( Alma 34:14 ) .
# Target:		These false prophets and their followers “ did not believe in the repentance of their sins ” ( Alma 15:15 ) .
#
# Spanish:	Para la sorpresa del élder Asay , seguidamente Peter Mourik entró al salón y tomó su lugar frente al púlpito .
# Translation:	For the final event , Elder Peter walked the door , he walked the place of his pulpit .
# Target:		To the astonishment of Elder Asay , Peter Mourik immediately walked into the room and took his place at the podium .
#
# Spanish:	En nuestro hogar a nuestros niños les gustaba armar rompecabezas ; probablemente todos hemos tenido la oportunidad de armar uno .
# Translation:	In our home , our children wanted to all the time we have had had had had had the opportunity to one of the opportunity .
# Target:		In our home our children liked to do jigsaw puzzles . We have probably all had the opportunity to do a puzzle .
#
# Spanish:	Y mediante la compañía constante del poder santificador del Espíritu Santo , podemos retener siempre la remisión de nuestros pecados .
# Translation:	And through the companionship of the Holy Ghost , we can always remember the remission of our sins .
# Target:		By the sanctifying power of the Holy Ghost as our constant companion , we can always retain a remission of our sins .
#
# Spanish:	Después escucharemos al élder Quentin L. Cook y al élder Gary E. Stevenson , del Cuórum de los Doce Apóstoles .
# Translation:	Then we will hear Elder Quentin L. Cook and Gary E. Stevenson as Elder Stevenson of the Quorum of the Twelve Apostles .
# Target:		Following the singing , we will hear from Elders Quentin L. Cook and Gary E. Stevenson of the Quorum of the Twelve Apostles .
#
# Spanish:	Aunque no tiene nada de malo usar expertos , seamos realistas : nunca habrá suficientes para resolver todos los problemas .
# Translation:	Although it is nothing of us to use , we are never enough to be enough to be better problems .
# Target:		While there is nothing wrong with experts , let ’s face it : there will never be enough of them to solve all the problems .
#
# Spanish:	Por medio de Cristo , las personas pueden cambiar sus vidas , como de hecho lo hacen , y obtener redención .
# Translation:	Through Christ , Christ can change your lives as your life , as they make it done .
# Target:		Through Christ , people can and do change their lives and obtain redemption .
#
# Spanish:	Primero : Oren pidiendo específicamente que cada día puedan hacer que alguien se acerque más al Salvador y a Su evangelio .
# Translation:	First , for each day that we may do more than someone who can be the Savior and His gospel .
# Target:		First , specifically pray to bring someone closer to the Savior and His gospel every day .
#
# ...
# Translation:	I am singing : " I am a commitment to my Heavenly Father and the same effort to do the best effort of the rest of my life , but I will be done for the rest of my life , and I will do n’t have a great mission , and I will be a great mission ,
# Target:		I wrote : " I have pledged with my Father in Heaven and with myself to do my very best , to give it 100 percent for the rest of my life , whatever I am asked , I 'll do , but for now I have the rest of my mission and I am going to make it a great mission , one that I wo n't feel bad about , but not for me , for the Lord .
#
# Spanish:	" Sino que soy como vosotros , sujeto a toda clase de enfermedades de cuerpo y mente ; sin embargo , he sido elegido por este pueblo , y ungido por mi padre , y la mano del Señor permitió que yo fuese gobernante y rey de este pueblo ; y su incomparable poder me ha guardado y preservado , para serviros con todo el poder , mente y fuerza que el Señor me ha concedido " ( Mosíah 2:10–11 ) .
# Translation:	" But as ye have done to you , every class of body of body , and mind ; but I have been chosen for this people , and gave to pass from the Lord , the hand of the Lord , who has been the power of the Lord .
